# %%
import argparse
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv

import cv2

import torch
import torch.nn as nn
import torch.nn.functional as F
# from torchvision import utils, datasets, transforms

import time
import scipy
import sys
import os
import shutil
import random

# %%
faces_dir_original = './datasets/att_faces'
faces_dir_compress = './datasets/att_faces_compress'
faces_dir_restore = './datasets/att_faces_restore'

# %%
def compress_faces():													# *** COMMENTS ***
	faces_count = 40  
	imgs_compressed = []                                                        # directory path to the AT&T faces                                                                 # length of the column vector

	print('> Initializing started')

	faces_dir = './datasets/att_faces'
	# compress_dir = './datasets/att_faces_compress'
	training_ids = []                                                  # train image id's for every at&t face

	cur_img = 0
	for face_id in range(1, faces_count + 1):
		print(face_id)
		training_ids = range(1, 11)
		for training_id in training_ids:
			path_to_img = os.path.join(faces_dir,
					's' + str(face_id), str(training_id) + '.pgm')          # relative path
			print('> reading file: ' + path_to_img)
			img = cv2.imread(path_to_img, 0)                                # read a grayscale image
			img_data = torch.from_numpy(img.astype(np.float32)).unsqueeze(0)
			img_data = img_data.unsqueeze(0)/255  #shape [batch, C, H, W]
			img_data = img_data*2 - 1 # normalize to [-1, 1]

			B, C, H, W = img_data.shape # data: shape [batch, 3, H, W] where 3 means RGB channels, batch=10, H=W=32

			compressed_img = torch.nn.functional.interpolate(img_data, scale_factor=0.5, mode='bilinear')
			X_data = torch.nn.functional.interpolate(compressed_img, scale_factor=2, mode='nearest')
			X_data = torch.clamp(X_data[0].squeeze(0), min=-1.0, max=1.0)
			X_data = X_data / 2 + 0.5
			X_data_np = X_data.cpu().data.numpy()
			print('> downsample using bilinear interpolation: ' + str(compressed_img.shape))
			print('> upsample using nearest interpolation: ' + str(X_data.shape))
			print('> saving compressed np array: ' + str(X_data_np.shape))
			path_to_compress = os.path.join(faces_dir_compress,
					's' + str(face_id), str(training_id) + '.npy')          # relative path
			path_to_ori = os.path.join(faces_dir,
		's' + str(face_id), str(training_id) + '.npy')          # relative path
			np.save(path_to_ori, img)
			np.save(path_to_compress, X_data_np)
			
			imgs_compressed.append(X_data_np)
	imgs_compressed = np.array(imgs_compressed)
	return imgs_compressed

# %%
imgs_compressed = compress_faces() #compress first, then interpolate using nearest, will be used as X
# Out:
# > Initializing started
# 1
# > reading file: ./datasets/att_faces/s1/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 2
# > reading file: ./datasets/att_faces/s2/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 3
# > reading file: ./datasets/att_faces/s3/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 4
# > reading file: ./datasets/att_faces/s4/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 5
# > reading file: ./datasets/att_faces/s5/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 6
# > reading file: ./datasets/att_faces/s6/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 7
# > reading file: ./datasets/att_faces/s7/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 8
# > reading file: ./datasets/att_faces/s8/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 9
# > reading file: ./datasets/att_faces/s9/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 10
# > reading file: ./datasets/att_faces/s10/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 11
# > reading file: ./datasets/att_faces/s11/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 12
# > reading file: ./datasets/att_faces/s12/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 13
# > reading file: ./datasets/att_faces/s13/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 14
# > reading file: ./datasets/att_faces/s14/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 15
# > reading file: ./datasets/att_faces/s15/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 16
# > reading file: ./datasets/att_faces/s16/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 17
# > reading file: ./datasets/att_faces/s17/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 18
# > reading file: ./datasets/att_faces/s18/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 19
# > reading file: ./datasets/att_faces/s19/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 20
# > reading file: ./datasets/att_faces/s20/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 21
# > reading file: ./datasets/att_faces/s21/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 22
# > reading file: ./datasets/att_faces/s22/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# ...
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s33/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s33/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 34
# > reading file: ./datasets/att_faces/s34/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 35
# > reading file: ./datasets/att_faces/s35/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 36
# > reading file: ./datasets/att_faces/s36/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 37
# > reading file: ./datasets/att_faces/s37/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 38
# > reading file: ./datasets/att_faces/s38/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 39
# > reading file: ./datasets/att_faces/s39/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# 40
# > reading file: ./datasets/att_faces/s40/1.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/2.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/3.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/4.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/5.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/6.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/7.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/8.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/9.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/10.pgm
# > downsample using bilinear interpolation: torch.Size([1, 1, 56, 46])
# > upsample using nearest interpolation: torch.Size([112, 92])
# > saving compressed np array: (112, 92)

# %%
def plot_one_image(img):
    # plt.imshow('image window', img)
    # plt.imshow(img.cpu().data.numpy())
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
plot_one_image(imgs_compressed[0])

# %%
def STEM(inputs, channel=3):
    '''
    return: stem features with shape [batchxHxW, 3xkernelxkernel] where batch=10, H=W=32, kernel=3
    '''
    kernel = 3
    B, C, H, W = inputs.shape
    X = []
    inputs_with_padding = torch.cat((inputs,torch.zeros((B,C,H,kernel))),-1)
    inputs_with_padding = torch.cat((inputs_with_padding,torch.zeros(B,C,kernel,W+kernel)),-2)
    for i in range(inputs.shape[2]):
        row = []
        for j in range(inputs.shape[3]):
            row.append(inputs_with_padding[:,:,i:i+kernel,j:j+kernel])
        X.append(row)
    X = torch.stack([torch.stack(x,2) for x in X],2).permute(0,2,3,1,4,5)
    return X.reshape(-1,channel*kernel*kernel)

# %%
def DPCA_eig(Y, X, m): #here we minimize $\| Y - F U X \|^2$
    # Y: (3,BHW), X: (27, BHW)
    n,p = X.size()
    XYt = torch.mm(X, Y.t())
    RM = torch.mm(torch.inverse(torch.mm(X, X.t())+1e-3*torch.eye(X.shape[0])),
			        torch.mm(XYt, XYt.t()))
    eigenvalues, eigenvectors = torch.linalg.eig(RM)
    
    values, indices = torch.sort(eigenvalues.real, descending=True)
    
    U = (eigenvectors[:, indices[:m]]).t().real  #(m,27)
    explained_variance = values[:m]
    UX = torch.mm(U,X)
    F = torch.mm(torch.mm(Y, UX.t()),
                 torch.inverse(torch.mm(UX, UX.t())+1e-3*torch.eye(UX.shape[0])),
			        )
    W = torch.mm(F, U)   #W = FU is a rank-m matrix
    return { 'X':X, 'k':m, 'components':U, 'explained_variance':explained_variance,
            'W': W}

# %%
def CPCA(data, targets, num_components, channel=3):
    stem = STEM(data, channel=channel)  #(BHW,27)
    PCA_output = DPCA_eig(targets, stem.t(), m=num_components) # m is number of components
    # components = PCA_output['components']
    weights = PCA_output['W']
    return stem, weights

# %%
def run_faces(img):
    # load babyface image
    # img = Image.open('results/baby_mini_d3_gaussian.jpg')
    # img_data = torch.from_numpy(np.asarray(img).astype(np.float32))
    img_data = torch.from_numpy(img.astype(np.float32)).unsqueeze(0)
    img_data = img_data.unsqueeze(0)/255  #shape [batch, C, H, W]
    img_data = img_data*2 - 1 # normalize to [-1, 1]

    B, C, H, W = img_data.shape # data: shape [batch, 3, H, W] where 3 means RGB channels, batch=10, H=W=32

    compressed_img = torch.nn.functional.interpolate(img_data, scale_factor=0.5, mode='bilinear')
    X_data = torch.nn.functional.interpolate(compressed_img, scale_factor=2, mode='nearest')

    targets = img_data.permute(0,2,3,1).reshape(-1, C).float().t() # (1, 112*92)
    stem, weights = CPCA(X_data, targets, 1, channel=1) #(112*92,9), (1,9)
    featuremaps = torch.matmul(weights, stem.t()).reshape(B, H, W)

    restored_img = torch.clamp(featuremaps[0].squeeze(0), min=-1.0, max=1.0)
    restored_img = restored_img / 2 + 0.5
    return restored_img.cpu().data.numpy()

# %%
def restore_faces():													# *** COMMENTS ***
	faces_count = 40                                                          # directory path to the AT&T faces                                                      # number of faces used for training
	print('> Initializing started')

	faces_dir = './datasets/att_faces'
	imgs_restore = []
	training_ids = []                                                  # train image id's for every at&t face


	cur_img = 0
	for face_id in range(1, faces_count + 1):
		print(face_id)
		training_ids = range(1, 11)
		for training_id in training_ids:
			path_to_img = os.path.join(faces_dir,
					's' + str(face_id), str(training_id) + '.pgm')          # relative path
			print('> reading file: ' + path_to_img)
			img = cv2.imread(path_to_img, 0)                                # read a grayscale image
			img_restore = run_faces(img)
			print('> restoring by deepPCA (w=3): ' + str(img_restore.shape))
			print('> saving restored np array: ' + str(img_restore.shape))
			path_to_restore_npy = os.path.join(faces_dir_restore,
					's' + str(face_id), str(training_id) + '.npy')
			np.save(path_to_restore_npy, img_restore)
			imgs_restore.append(img_restore)
	imgs_restore = np.array(imgs_restore)
	return imgs_restore

# %%
imgs_restore = restore_faces()
# Out:
# > Initializing started
# 1
# > reading file: ./datasets/att_faces/s1/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s1/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 2
# > reading file: ./datasets/att_faces/s2/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s2/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 3
# > reading file: ./datasets/att_faces/s3/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s3/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 4
# > reading file: ./datasets/att_faces/s4/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s4/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 5
# > reading file: ./datasets/att_faces/s5/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s5/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 6
# > reading file: ./datasets/att_faces/s6/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s6/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 7
# > reading file: ./datasets/att_faces/s7/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s7/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 8
# > reading file: ./datasets/att_faces/s8/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s8/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 9
# > reading file: ./datasets/att_faces/s9/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s9/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 10
# > reading file: ./datasets/att_faces/s10/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s10/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 11
# > reading file: ./datasets/att_faces/s11/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s11/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 12
# > reading file: ./datasets/att_faces/s12/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s12/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 13
# > reading file: ./datasets/att_faces/s13/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s13/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 14
# > reading file: ./datasets/att_faces/s14/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s14/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 15
# > reading file: ./datasets/att_faces/s15/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s15/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 16
# > reading file: ./datasets/att_faces/s16/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s16/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 17
# > reading file: ./datasets/att_faces/s17/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s17/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 18
# > reading file: ./datasets/att_faces/s18/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s18/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 19
# > reading file: ./datasets/att_faces/s19/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s19/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 20
# > reading file: ./datasets/att_faces/s20/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s20/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 21
# > reading file: ./datasets/att_faces/s21/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s21/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 22
# > reading file: ./datasets/att_faces/s22/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s22/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 23
# > reading file: ./datasets/att_faces/s23/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s23/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s23/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s23/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s23/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s23/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s23/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s23/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s23/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s23/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 24
# > reading file: ./datasets/att_faces/s24/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s24/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s24/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s24/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s24/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s24/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s24/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s24/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s24/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s24/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 25
# > reading file: ./datasets/att_faces/s25/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s25/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s25/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s25/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s25/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s25/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s25/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s25/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s25/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s25/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 26
# > reading file: ./datasets/att_faces/s26/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s26/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s26/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s26/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s26/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s26/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s26/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s26/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s26/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s26/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 27
# > reading file: ./datasets/att_faces/s27/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s27/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s27/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s27/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s27/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s27/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s27/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s27/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s27/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s27/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 28
# > reading file: ./datasets/att_faces/s28/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s28/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s28/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s28/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s28/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s28/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s28/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s28/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s28/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s28/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 29
# > reading file: ./datasets/att_faces/s29/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s29/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s29/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s29/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s29/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s29/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s29/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s29/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s29/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s29/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 30
# > reading file: ./datasets/att_faces/s30/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s30/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s30/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s30/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s30/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s30/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s30/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s30/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s30/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s30/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 31
# > reading file: ./datasets/att_faces/s31/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s31/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s31/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s31/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s31/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s31/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s31/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s31/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s31/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s31/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 32
# > reading file: ./datasets/att_faces/s32/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s32/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s32/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s32/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s32/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s32/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s32/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s32/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s32/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s32/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 33
# > reading file: ./datasets/att_faces/s33/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s33/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s33/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s33/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s33/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s33/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s33/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s33/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s33/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s33/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 34
# > reading file: ./datasets/att_faces/s34/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s34/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 35
# > reading file: ./datasets/att_faces/s35/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s35/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 36
# > reading file: ./datasets/att_faces/s36/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s36/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 37
# > reading file: ./datasets/att_faces/s37/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s37/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 38
# > reading file: ./datasets/att_faces/s38/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s38/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 39
# > reading file: ./datasets/att_faces/s39/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s39/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# 40
# > reading file: ./datasets/att_faces/s40/1.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/2.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/3.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/4.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/5.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/6.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/7.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/8.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/9.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)
# > reading file: ./datasets/att_faces/s40/10.pgm
# > restoring by deepPCA (w=3): (112, 92)
# > saving restored np array: (112, 92)

# %%
plot_one_image(imgs_restore[0])

# %% [markdown]
# # Train

# %%
class Eigenfaces(object):                                                       # *** COMMENTS ***
    faces_count = 40

    faces_dir = '.'                                                             # directory path to the AT&T faces

    train_faces_count = 6                                                       # number of faces used for training
    test_faces_count = 4                                                       # number of faces used for testing

    l = train_faces_count * faces_count                                         # training images count
    m = 92                                                                      # number of columns of the image
    n = 112                                                                     # number of rows of the image
    mn = m * n                                                                  # length of the column vector

    """
    Initializing the Eigenfaces model.
    """

    def __init__(self,_faces_dir = '.'):
        print('> Initializing started')

        self.faces_dir = _faces_dir
        self.energy = 0.85
        self.training_ids = []                                                  # train image id's for every at&t face

        L = np.empty(shape=(self.mn, self.l), dtype='float64')                  # each row of L represents one train image

        cur_img = 0
        for face_id in range(1, self.faces_count + 1):

            training_ids = random.sample(range(1, 11), self.train_faces_count)  # the id's of the 6 random training images
            self.training_ids.append(training_ids)                              # remembering the training id's for later

            for training_id in training_ids:
                path_to_img = os.path.join(self.faces_dir,
                        's' + str(face_id), str(training_id) + '.npy')          # relative path
                # print '> reading file: ' + path_to_img
                img = np.load(path_to_img)
                # img = cv2.imread(path_to_img, 0) 
                #                               # read a grayscale image
                if face_id < 2 and training_id<3:
                    plot_one_image(img)
                img_col = np.array(img, dtype='float64').flatten()              # flatten the 2d image into 1d

                L[:, cur_img] = img_col[:]                                      # set the cur_img-th column to the current training image
                cur_img += 1

        self.mean_img_col = np.sum(L, axis=1) / self.l                          # get the mean of all images / over the rows of L

        for j in range(0, self.l):                                             # subtract from all training images
            L[:, j] -= self.mean_img_col[:]

        C = np.matrix(L.transpose()) * np.matrix(L)                             # instead of computing the covariance matrix as
        C /= self.l                                                             # L*L^T, we set C = L^T*L, and end up with way
                                                                                # smaller and computentionally inexpensive one
                                                                                # we also need to divide by the number of training
        # data = torch.from_numpy(np.matrix(L.transpose())).reshape(self.l, 92, 112).unsqueeze(1)   #[320, 1, 92, 112]
        # stem = STEM(data, channel=1)  #[3297280, 9]
        # X = stem.reshape(self.l, 92*112, 9).reshape(self.l,-1).t()  #[HW9, 320]
        # Y = torch.from_numpy(np.matrix(L))                                 #[HW, 320]
        
        # XYt = torch.mm(X, Y.t())
        # # RM = torch.mm(torch.inverse(torch.mm(X, X.t())+1e-3*torch.eye(X.shape[0])),
        # #                 torch.mm(XYt, XYt.t()))
        # RM_ = torch.mm(X.t(),torch.inverse(torch.mm(X, X.t())+1e-3*torch.eye(X.shape[0])),
        #                 torch.mm(XYt, Y))
        # eigenvalues, eigenvectors = torch.linalg.eig(RM_)
        
        # values, indices = torch.sort(eigenvalues.real, descending=True)
        
        # m=50
        # U = (eigenvectors[:, indices[:m]]).t().real  #(m,HW9)
        
        values, eigenvectors = np.linalg.eig(C)                          # eigenvectors/values of the covariance matrix
        indices = values.argsort()[::-1]                             # getting their correct order - decreasing
        self.evalues = values[indices]                               # puttin the evalues in that order
        self.evectors = eigenvectors[:,indices]                             # same for the evectors

        evalues_sum = sum(self.evalues[:])                                      # include only the first k evectors/values so
        evalues_count = 0                                                       # that they include approx. 85% of the energy
        evalues_energy = 0.0
        for evalue in self.evalues:
            evalues_count += 1
            evalues_energy += evalue / evalues_sum

            if evalues_energy >= self.energy:
                break

        self.evalues = self.evalues[0:evalues_count]                            # reduce the number of eigenvectors/values to consider
        self.evectors = self.evectors[:,0:evalues_count]

        self.evectors = L * self.evectors    #(HW,62)
        norms = np.linalg.norm(self.evectors, axis=0)                           # find the norm of each eigenvector
        self.evectors = self.evectors / norms                                   # normalize all eigenvectors

        self.W = self.evectors.transpose() * L       #(62,320)

        print('> Initializing ended')
    """
    Classify an image to one of the eigenfaces.
    """
    def classify(self, path_to_img):
        # img = cv2.imread(path_to_img, 0)                                        # read as a grayscale image
        img = np.load(path_to_img)
        img_col = np.array(img, dtype='float64').flatten()                      # flatten the image
        img_col -= self.mean_img_col                                            # subract the mean column
        img_col = np.reshape(img_col, (self.mn, 1))                             # from row vector to col vector

        S = self.evectors.transpose() * img_col                                 # projecting the normalized probe onto the
                                                                                # Eigenspace, to find out the weights

        diff = self.W - S                                                       # finding the min ||W_j - S||
        norms = np.linalg.norm(diff, axis=0)

        closest_face_id = np.argmin(norms)                                      # the id [0..240) of the minerror face to the sample
        return int(closest_face_id / self.train_faces_count) + 1                   # return the faceid (1..40)

    """
    Evaluate the model using the 4 test faces left
    from every different face in the AT&T set.
    """
    def evaluate(self):
        print('> Evaluating AT&T faces started')
        results_file = os.path.join('results', 'att_restore_results.txt')               # filename for writing the evaluating results in
        f = open(results_file, 'w')                                             # the actual file

        test_count = self.test_faces_count * self.faces_count                   # number of all AT&T test images/faces
        test_correct = 0
        for face_id in range(1, self.faces_count + 1):
            for test_id in range(1, 11):
                if (test_id in self.training_ids[face_id-1]) == False:          # we skip the image if it is part of the training set
                    path_to_img = os.path.join(self.faces_dir,
                            's' + str(face_id), str(test_id) + '.npy')          # relative path

                    result_id = self.classify(path_to_img)
                    result = (result_id == face_id)

                    if result == True:
                        test_correct += 1
                        f.write('image: %s\nresult: correct\n\n' % path_to_img)
                    else:
                        f.write('image: %s\nresult: wrong, got %2d\n\n' %
                                (path_to_img, result_id))

        print('> Evaluating AT&T faces ended')
        self.accuracy = float(100. * test_correct / test_count)
        print('Correct: ' + str(self.accuracy) + '%')
        f.write('Correct: %.2f\n' % (self.accuracy))
        f.close()

# %% [markdown]
# ## PCA - original

# %%
random.seed(2)
faces = None
faces = Eigenfaces('./datasets/att_faces')
faces.evaluate()
# Out:
# > Initializing started
# > Initializing ended
# > Evaluating AT&T faces started
# > Evaluating AT&T faces ended
# Correct: 96.25%

# %% [markdown]
# ## PCA - 4 times compressed

# %%
random.seed(4)
faces = None
faces = Eigenfaces('./datasets/att_faces_compress')
faces.evaluate()
# Out:
# > Initializing started
# > Initializing ended
# > Evaluating AT&T faces started
# > Evaluating AT&T faces ended
# Correct: 96.25%

# %% [markdown]
# ## PCA - restore

# %%
random.seed(2) #2
faces = None
faces = Eigenfaces('./datasets/att_faces_restore')
faces.evaluate()
# Out:
# > Initializing started
# > Initializing ended
# > Evaluating AT&T faces started
# > Evaluating AT&T faces ended
# Correct: 97.5%

# %% [markdown]
# ## Improvement
# 97.5 - 96.25= 0.625

# %% [markdown]
# ## Visualization
